# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
train_dataset_path = '/content/drive/MyDrive/HP/train'
validation_dataset_path = '/content/drive/MyDrive/HP/val'

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 312 images belonging to 6 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 302 images belonging to 6 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Other
# 1 : vasisthasana
# 2 : viparita karani
# 3 : vriksasana
# 4 : vrischikasana
# 5 : yoganidrasana

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Flatten(),

        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=6, activation='softmax')
    ])

    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 128)     9728
#
#  activation (Activation)     (None, 146, 146, 128)     0
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 128)       0
#  D)
#
#  batch_normalization (Batch  (None, 73, 73, 128)       512
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 71, 71, 64)        73792
#
#  activation_1 (Activation)   (None, 71, 71, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 35, 35, 64)        256
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 33, 33, 32)        18464
#
#  activation_2 (Activation)   (None, 33, 33, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 2201830 (8.40 MB)
# Trainable params: 2201382 (8.40 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
#cnn_model.add(Dense(6, activation='softmax'))

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 10/10 - 93s - loss: 3.3175 - accuracy: 0.3205 - val_loss: 1.7808 - val_accuracy: 0.2219 - lr: 0.0010 - 93s/epoch - 9s/step
# Epoch 2/50
# 10/10 - 60s - loss: 3.4862 - accuracy: 0.3814 - val_loss: 1.8995 - val_accuracy: 0.1854 - lr: 0.0010 - 60s/epoch - 6s/step
# Epoch 3/50
# 10/10 - 68s - loss: 2.9445 - accuracy: 0.4904 - val_loss: 1.7276 - val_accuracy: 0.3113 - lr: 0.0010 - 68s/epoch - 7s/step
# Epoch 4/50
# 10/10 - 61s - loss: 2.8196 - accuracy: 0.4808 - val_loss: 2.7993 - val_accuracy: 0.2781 - lr: 0.0010 - 61s/epoch - 6s/step
# Epoch 5/50
# 10/10 - 68s - loss: 2.3259 - accuracy: 0.5288 - val_loss: 2.1002 - val_accuracy: 0.2053 - lr: 0.0010 - 68s/epoch - 7s/step
# Epoch 6/50
# 10/10 - 69s - loss: 1.8082 - accuracy: 0.6282 - val_loss: 2.0244 - val_accuracy: 0.3179 - lr: 0.0010 - 69s/epoch - 7s/step
# Epoch 7/50
# 10/10 - 70s - loss: 1.7836 - accuracy: 0.5449 - val_loss: 1.9888 - val_accuracy: 0.2550 - lr: 0.0010 - 70s/epoch - 7s/step
# Epoch 8/50
# 10/10 - 71s - loss: 1.6456 - accuracy: 0.6090 - val_loss: 1.9589 - val_accuracy: 0.3940 - lr: 0.0010 - 71s/epoch - 7s/step
# Epoch 9/50
# 10/10 - 70s - loss: 2.0006 - accuracy: 0.5994 - val_loss: 1.6991 - val_accuracy: 0.4205 - lr: 3.1623e-04 - 70s/epoch - 7s/step
# Epoch 10/50
# 10/10 - 61s - loss: 1.6001 - accuracy: 0.6090 - val_loss: 1.9373 - val_accuracy: 0.3742 - lr: 3.1623e-04 - 61s/epoch - 6s/step
# Epoch 11/50
# 10/10 - 68s - loss: 1.5479 - accuracy: 0.6442 - val_loss: 1.9148 - val_accuracy: 0.4139 - lr: 3.1623e-04 - 68s/epoch - 7s/step
# Epoch 12/50
# 10/10 - 61s - loss: 1.1993 - accuracy: 0.6731 - val_loss: 2.1603 - val_accuracy: 0.2285 - lr: 3.1623e-04 - 61s/epoch - 6s/step
# Epoch 13/50
# 10/10 - 62s - loss: 1.1295 - accuracy: 0.6891 - val_loss: 1.9327 - val_accuracy: 0.3642 - lr: 3.1623e-04 - 62s/epoch - 6s/step
# Epoch 14/50
# 10/10 - 60s - loss: 1.0202 - accuracy: 0.7276 - val_loss: 1.5035 - val_accuracy: 0.5166 - lr: 3.1623e-04 - 60s/epoch - 6s/step
# Epoch 15/50
# 10/10 - 67s - loss: 1.0957 - accuracy: 0.6955 - val_loss: 1.3157 - val_accuracy: 0.5099 - lr: 3.1623e-04 - 67s/epoch - 7s/step
# Epoch 16/50
# 10/10 - 65s - loss: 1.0105 - accuracy: 0.7244 - val_loss: 1.4461 - val_accuracy: 0.3874 - lr: 3.1623e-04 - 65s/epoch - 6s/step
# Epoch 17/50
# 10/10 - 65s - loss: 0.8137 - accuracy: 0.7308 - val_loss: 1.6815 - val_accuracy: 0.3477 - lr: 3.1623e-04 - 65s/epoch - 7s/step
# Epoch 18/50
# 10/10 - 68s - loss: 0.9674 - accuracy: 0.7244 - val_loss: 1.6176 - val_accuracy: 0.4503 - lr: 3.1623e-04 - 68s/epoch - 7s/step
# Epoch 19/50
# 10/10 - 69s - loss: 0.9252 - accuracy: 0.7179 - val_loss: 1.4606 - val_accuracy: 0.4603 - lr: 3.1623e-04 - 69s/epoch - 7s/step
# Epoch 20/50
# 10/10 - 68s - loss: 0.8857 - accuracy: 0.7244 - val_loss: 1.6613 - val_accuracy: 0.3675 - lr: 3.1623e-04 - 68s/epoch - 7s/step
# Epoch 21/50
# 10/10 - 67s - loss: 0.7735 - accuracy: 0.7596 - val_loss: 1.7321 - val_accuracy: 0.3510 - lr: 1.0000e-04 - 67s/epoch - 7s/step
# Epoch 22/50
# 10/10 - 65s - loss: 0.7176 - accuracy: 0.7788 - val_loss: 1.4290 - val_accuracy: 0.4470 - lr: 1.0000e-04 - 65s/epoch - 6s/step
# Epoch 23/50
# 10/10 - 65s - loss: 0.7864 - accuracy: 0.7628 - val_loss: 1.2140 - val_accuracy: 0.5596 - lr: 1.0000e-04 - 65s/epoch - 6s/step
# Epoch 24/50
# 10/10 - 64s - loss: 0.6696 - accuracy: 0.7949 - val_loss: 1.2641 - val_accuracy: 0.5199 - lr: 1.0000e-04 - 64s/epoch - 6s/step
# Epoch 25/50
# 10/10 - 64s - loss: 0.5401 - accuracy: 0.7981 - val_loss: 1.3032 - val_accuracy: 0.5199 - lr: 1.0000e-04 - 64s/epoch - 6s/step
# Epoch 26/50
# 10/10 - 64s - loss: 0.6397 - accuracy: 0.7724 - val_loss: 1.2080 - val_accuracy: 0.5430 - lr: 1.0000e-04 - 64s/epoch - 6s/step
# Epoch 27/50
# 10/10 - 68s - loss: 0.7704 - accuracy: 0.7500 - val_loss: 1.1919 - val_accuracy: 0.5497 - lr: 1.0000e-04 - 68s/epoch - 7s/step
# Epoch 28/50
# 10/10 - 67s - loss: 0.6628 - accuracy: 0.8173 - val_loss: 1.1544 - val_accuracy: 0.5861 - lr: 1.0000e-04 - 67s/epoch - 7s/step
# Epoch 29/50
# 10/10 - 66s - loss: 0.5009 - accuracy: 0.8205 - val_loss: 1.1724 - val_accuracy: 0.5960 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 30/50
# 10/10 - 65s - loss: 0.5792 - accuracy: 0.8365 - val_loss: 1.1334 - val_accuracy: 0.6159 - lr: 1.0000e-04 - 65s/epoch - 6s/step
# Epoch 31/50
# 10/10 - 59s - loss: 0.6148 - accuracy: 0.8013 - val_loss: 1.0141 - val_accuracy: 0.6325 - lr: 1.0000e-04 - 59s/epoch - 6s/step
# Epoch 32/50
# 10/10 - 66s - loss: 0.5710 - accuracy: 0.8109 - val_loss: 1.0000 - val_accuracy: 0.6556 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 33/50
# 10/10 - 66s - loss: 0.5879 - accuracy: 0.7949 - val_loss: 0.9609 - val_accuracy: 0.6755 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 34/50
# 10/10 - 65s - loss: 0.5588 - accuracy: 0.8333 - val_loss: 0.9153 - val_accuracy: 0.6921 - lr: 1.0000e-04 - 65s/epoch - 7s/step
# Epoch 35/50
# 10/10 - 68s - loss: 0.5553 - accuracy: 0.8397 - val_loss: 0.9254 - val_accuracy: 0.6987 - lr: 1.0000e-04 - 68s/epoch - 7s/step
# Epoch 36/50
# 10/10 - 67s - loss: 0.6307 - accuracy: 0.8077 - val_loss: 0.9503 - val_accuracy: 0.7053 - lr: 1.0000e-04 - 67s/epoch - 7s/step
# Epoch 37/50
# 10/10 - 66s - loss: 0.6120 - accuracy: 0.8429 - val_loss: 0.9407 - val_accuracy: 0.6821 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 38/50
# 10/10 - 66s - loss: 0.4227 - accuracy: 0.8365 - val_loss: 1.0132 - val_accuracy: 0.6325 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 39/50
# 10/10 - 65s - loss: 0.5877 - accuracy: 0.8429 - val_loss: 0.9089 - val_accuracy: 0.6854 - lr: 1.0000e-04 - 65s/epoch - 6s/step
# Epoch 40/50
# 10/10 - 66s - loss: 0.4764 - accuracy: 0.8462 - val_loss: 0.7560 - val_accuracy: 0.7649 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 41/50
# 10/10 - 68s - loss: 0.5441 - accuracy: 0.8494 - val_loss: 0.6156 - val_accuracy: 0.7881 - lr: 1.0000e-04 - 68s/epoch - 7s/step
# Epoch 42/50
# 10/10 - 67s - loss: 0.5660 - accuracy: 0.8333 - val_loss: 0.6565 - val_accuracy: 0.7815 - lr: 1.0000e-04 - 67s/epoch - 7s/step
# Epoch 43/50
# 10/10 - 66s - loss: 0.4497 - accuracy: 0.8718 - val_loss: 0.6658 - val_accuracy: 0.7815 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 44/50
# 10/10 - 59s - loss: 0.4876 - accuracy: 0.8397 - val_loss: 0.5495 - val_accuracy: 0.8311 - lr: 1.0000e-04 - 59s/epoch - 6s/step
# Epoch 45/50
# 10/10 - 60s - loss: 0.5074 - accuracy: 0.8686 - val_loss: 0.5583 - val_accuracy: 0.8113 - lr: 1.0000e-04 - 60s/epoch - 6s/step
# Epoch 46/50
# 10/10 - 62s - loss: 0.4549 - accuracy: 0.8301 - val_loss: 0.4949 - val_accuracy: 0.8510 - lr: 1.0000e-04 - 62s/epoch - 6s/step
# Epoch 47/50
# 10/10 - 68s - loss: 0.3498 - accuracy: 0.8750 - val_loss: 0.4420 - val_accuracy: 0.8576 - lr: 1.0000e-04 - 68s/epoch - 7s/step
# Epoch 48/50
# 10/10 - 68s - loss: 0.3916 - accuracy: 0.8782 - val_loss: 0.3654 - val_accuracy: 0.8940 - lr: 1.0000e-04 - 68s/epoch - 7s/step
# Epoch 49/50
# 10/10 - 66s - loss: 0.3931 - accuracy: 0.8494 - val_loss: 0.3301 - val_accuracy: 0.9073 - lr: 1.0000e-04 - 66s/epoch - 7s/step
# Epoch 50/50
# 10/10 - 66s - loss: 0.3776 - accuracy: 0.8654 - val_loss: 0.2982 - val_accuracy: 0.9073 - lr: 1.0000e-04 - 66s/epoch - 7s/step

# %%
cnn_model.save('model.h5')

# %%
from keras.models import load_model

# %%
loaded_model = load_model('model.h5')

# %%
#i. Plotting training and validation accuracy, loss and learning rate
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
test_dataset = '/content/drive/MyDrive/HP/test'

# %%
#test_dataset = '/content/drive/MyDrive/HP/train/viparita karani'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 312 images belonging to 6 classes.

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 10/10 [==============================] - 15s 2s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 10/10 [==============================] - 13s 1s/step - loss: 0.1909 - accuracy: 0.9776

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.19091373682022095
# Test Accuracy: 0.9775640964508057

# %%
#i. Confusion Matrix
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(6, 6)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#                  precision    recall  f1-score   support
#
#           Other       1.00      1.00      1.00        10
#    vasisthasana       0.97      0.97      0.97        74
# viparita karani       0.97      1.00      0.99        69
#      vriksasana       1.00      0.98      0.99        62
#   vrischikasana       1.00      0.94      0.97        51
#   yoganidrasana       0.94      0.98      0.96        46
#
#        accuracy                           0.98       312
#       macro avg       0.98      0.98      0.98       312
#    weighted avg       0.98      0.98      0.98       312

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-c5ffdf4a8b60> in <cell line: 24>()
#      22
#      23 # Make predictions
# ---> 24 predictions = cnn_model.predict(img_array)
#      25
#      26 # Decode the predictions (this depends on your model architecture)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2416, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2401, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2389, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2357, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_3" is incompatible with the layer: expected shape=(None, 150, 150, 3), found shape=(None, 224, 224, 3)
